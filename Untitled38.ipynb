# %% [markdown]
# <a href="https://colab.research.google.com/github/souvik25162/Machine-Learning/blob/master/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install statsmodels --upgrade
# Out:
# Requirement already up-to-date: statsmodels in /usr/local/lib/python3.6/dist-packages (0.11.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (1.18.5)
# Requirement already satisfied, skipping upgrade: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (0.5.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.21 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (1.0.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->statsmodels) (2018.9)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
import warnings
warnings.filterwarnings("ignore")
plt.style.use("fivethirtyeight")
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize']=14
matplotlib.rcParams['xtick.labelsize']=12
matplotlib.rcParams['ytick.labelsize']=12
matplotlib.rcParams['text.color']='k'

# %%
from google.colab import files
uploaded=files.upload()
df=pd.read_excel("germany.xlsx")
# Out:
#      <input type="file" id="files-66f93374-91cc-4ea1-8b3f-3e1fa0598f2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66f93374-91cc-4ea1-8b3f-3e1fa0598f2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving germany.xlsx to germany (4).xlsx

# %%
print("length of the dataset",df.shape)
print("minimum unemployment rate:",df['values'].min())
print("maximum unemployment rate:",df['values'].max())
df.head()
# Out:
# length of the dataset (468, 2)
# minimum unemployment rate: 3.0
# maximum unemployment rate: 12.1
#         DATE  values
# 0 1980-01-01     3.1
# 1 1980-02-01     3.0
# 2 1980-03-01     3.1
# 3 1980-04-01     3.2
# 4 1980-05-01     3.3

# %%
df['DATE']=pd.to_datetime(df['DATE'])

# %%
ts=df.sort_values('DATE')
print(df.isnull().sum())
ts=df.set_index("DATE")
ts.head()
# Out:
# DATE      0
# values    0
# dtype: int64
#             values
# DATE
# 1980-01-01     3.1
# 1980-02-01     3.0
# 1980-03-01     3.1
# 1980-04-01     3.2
# 1980-05-01     3.3

# %%
ts.plot(figsize=(10,4))

# %%
print(df['DATE'].max())
# Out:
# 2018-12-01 00:00:00

# %%
from statsmodels.tsa.stattools import adfuller,acf,pacf

def test_stationarity(series,mlag =None, lag = None,):
    print('ADF Test Result')
    res = adfuller(series, maxlag = mlag, autolag = lag)
    output = pd.Series(res[0:4],index = ['Test Statistic', 'p value', 'used lag', 'Number of observations used'])
    for key, value in res[4].items():
        output['Critical Value ' + key] = value
    print(output)

# %%
test_stationarity(df['values'])
# Out:
# ADF Test Result
# Test Statistic                  -1.923819
# p value                          0.320940
# used lag                        18.000000
# Number of observations used    449.000000
# Critical Value 1%               -3.444998
# Critical Value 5%               -2.867999
# Critical Value 10%              -2.570210
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
fig = plt.figure(figsize=(16,16))
ax1 = fig.add_subplot(411)
fig = plot_acf(df['values'],lags=200,ax=ax1)
plt.title('Autocorrelation Lag=200')
ax2 = fig.add_subplot(412)
fig = plot_pacf(df['values'],lags=200,ax=ax2)
plt.title('Partial Autocorrelation Lag=200')
ax3 = fig.add_subplot(413)
fig = plot_acf(df['values'],lags=15,ax=ax3)
plt.title('Autocorrelation Lag=15')
ax4 = fig.add_subplot(414)
fig = plot_pacf(df['values'],lags=15,ax=ax4)
plt.title('Partial Autocorrelation Lag=15')
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=None, hspace=0.5)
plt.show()

# %%
train=ts[0:432]
test= ts[432:len(ts)]
test1=ts[432:444]
test2=ts[432:456]

# %%
timeseries =train['values']
p,d,q = (4,1,1)
arima_mod = ARIMA(timeseries,(p,d,q)).fit()
summary = (arima_mod.summary2(alpha=.05, float_format="%.8f"))
print(summary)
# Out:
#                            Results: ARIMA
# ====================================================================
# Model:              ARIMA            BIC:                 -473.6487
# Dependent Variable: D.values         Log-Likelihood:      258.06
# Date:               2020-08-27 11:10 Scale:               1.0000
# No. Observations:   431              Method:              css-mle
# Df Model:           6                Sample:              02-01-1980
# Df Residuals:       425                                   12-01-2015
# Converged:          1.0000           S.D. of innovations: 0.133
# No. Iterations:     15.0000          HQIC:                -490.873
# AIC:                -502.1114
# ---------------------------------------------------------------------
#                   Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------
# const             0.0076    0.0184   0.4117  0.6805  -0.0285   0.0436
# ar.L1.D.values    0.7924    0.1424   5.5635  0.0000   0.5132   1.0715
# ar.L2.D.values    0.0273    0.0643   0.4244  0.6713  -0.0987   0.1533
# ar.L3.D.values    0.0428    0.0637   0.6711  0.5021  -0.0821   0.1676
# ar.L4.D.values    0.0232    0.0636   0.3644  0.7156  -0.1014   0.1477
# ma.L1.D.values   -0.6657    0.1349  -4.9357  0.0000  -0.9301  -0.4014
# -----------------------------------------------------------------------------
#                  Real           Imaginary          Modulus          Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1040            -0.0000           1.1040            -0.0000
# AR.2            0.6006            -3.0101           3.0694            -0.2187
# AR.3            0.6006             3.0101           3.0694             0.2187
# AR.4           -4.1514            -0.0000           4.1514            -0.5000
# MA.1            1.5021             0.0000           1.5021             0.0000
# ====================================================================

# %%
residuals= pd.DataFrame(arima_mod.resid)
residuals.plot()
plt.show()

residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                 0
# count  431.000000
# mean    -0.000179
# std      0.133095
# min     -0.461973
# 25%     -0.064757
# 50%      0.001262
# 75%      0.043781
# max      1.893823

# %%
test.head()
# Out:
#             values
# DATE
# 2016-01-01     6.2
# 2016-02-01     6.2
# 2016-03-01     6.2
# 2016-04-01     6.2
# 2016-05-01     6.1

# %%
train=train.values
test=test.values
test1=test1.values
test2=test2.values

# %%
history=[x for x in train]
predictions=list()

for t in range(len(test)):
  model=ARIMA(history,order=(4,1,1))
  model_fit=model.fit(disp=0)
  output=model_fit.forecast()
  yhat=output[0]
  predictions.append(yhat)
  obs=test[t]
  history.append(obs)
  print('predicted=%f, expected=%f'%(yhat,obs))
# Out:
# predicted=6.290113, expected=6.200000
# predicted=6.181387, expected=6.200000
# predicted=6.185732, expected=6.200000
# predicted=6.187078, expected=6.200000
# predicted=6.189862, expected=6.100000
# predicted=6.081236, expected=6.100000
# predicted=6.085612, expected=6.100000
# predicted=6.086979, expected=6.000000
# predicted=5.976879, expected=6.000000
# predicted=5.982684, expected=6.000000
# predicted=5.984854, expected=6.000000
# predicted=5.988351, expected=6.000000
# predicted=5.993057, expected=5.900000
# predicted=5.883357, expected=5.900000
# predicted=5.886955, expected=5.800000
# predicted=5.774927, expected=5.800000
# predicted=5.778766, expected=5.700000
# predicted=5.669630, expected=5.700000
# predicted=5.674989, expected=5.700000
# predicted=5.679898, expected=5.700000
# predicted=5.684847, expected=5.600000
# predicted=5.577901, expected=5.600000
# predicted=5.582973, expected=5.500000
# predicted=5.472583, expected=5.500000
# predicted=5.476666, expected=5.400000
# predicted=5.368552, expected=5.400000
# predicted=5.373736, expected=5.300000
# predicted=5.266763, expected=5.300000
# predicted=5.272299, expected=5.200000
# predicted=5.165978, expected=5.200000
# predicted=5.171532, expected=5.200000
# predicted=5.177999, expected=5.200000
# predicted=5.183096, expected=5.100000
# predicted=5.076888, expected=5.100000
# predicted=5.081648, expected=5.000000
# predicted=4.972348, expected=5.000000

# %%
from sklearn.metrics import mean_squared_error
error=mean_squared_error(test,predictions)
print("MSE:",error)

print("RMSE:",np.sqrt(error))
# Out:
# MSE: 0.0028555560690216057
# RMSE: 0.05343740327730761

# %%
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
history=[x for x in train]
predictions1=list()

for t in range(len(test1)):
  model=ARIMA(history,order=(4,1,1))
  model_fit2=model.fit(disp=0)
  output=model_fit2.forecast()
  yhat=output[0]
  predictions1.append(yhat)
  obs=test1[t]
  history.append(obs)
  print('predicted=%f, expected=%f'%(yhat,obs))
# Out:
# predicted=6.290113, expected=6.200000
# predicted=6.181387, expected=6.200000
# predicted=6.185732, expected=6.200000
# predicted=6.187078, expected=6.200000
# predicted=6.189862, expected=6.100000
# predicted=6.081236, expected=6.100000
# predicted=6.085612, expected=6.100000
# predicted=6.086979, expected=6.000000
# predicted=5.976879, expected=6.000000
# predicted=5.982684, expected=6.000000
# predicted=5.984854, expected=6.000000
# predicted=5.988351, expected=6.000000

# %%
from sklearn.metrics import mean_squared_error
error2=mean_squared_error(test1,predictions1)
print("MSE:",error2)

print("RMSE:",np.sqrt(error2))
# Out:
# MSE: 0.002186370750267951
# RMSE: 0.04675864358883768

# %%
history=[x for x in train]
predictions2=list()

for t in range(len(test2)):
  model=ARIMA(history,order=(4,1,0))
  model_fit2=model.fit(disp=0)
  output=model_fit2.forecast()
  yhat=output[0]
  predictions2.append(yhat)
  obs=test2[t]
  history.append(obs)
  print('predicted=%f, expected=%f'%(yhat,obs))
# Out:
# predicted=6.290699, expected=6.200000
# predicted=6.188322, expected=6.200000
# predicted=6.189414, expected=6.200000
# predicted=6.188661, expected=6.200000
# predicted=6.190439, expected=6.100000
# predicted=6.088217, expected=6.100000
# predicted=6.089306, expected=6.100000
# predicted=6.088556, expected=6.000000
# predicted=5.975274, expected=6.000000
# predicted=5.989204, expected=6.000000
# predicted=5.988307, expected=6.000000
# predicted=5.990102, expected=6.000000
# predicted=6.002921, expected=5.900000
# predicted=5.888011, expected=5.900000
# predicted=5.889079, expected=5.800000
# predicted=5.773326, expected=5.800000
# predicted=5.776026, expected=5.700000
# predicted=5.673330, expected=5.700000
# predicted=5.675725, expected=5.700000
# predicted=5.688055, expected=5.700000
# predicted=5.689690, expected=5.600000
# predicted=5.587791, expected=5.600000
# predicted=5.588551, expected=5.500000
# predicted=5.473232, expected=5.500000

# %%
error3=mean_squared_error(test2,predictions2)
print("MSE:",error3)

print("RMSE:",np.sqrt(error3))
# Out:
# MSE: 0.0028832448751351675
# RMSE: 0.053695855288235866

# %%
plt.plot(test1)
plt.plot(predictions1, color='red')
plt.show()

# %%
plt.plot(test2)
plt.plot(predictions2, color='red')
plt.show()

# %% [markdown]
# # ARNN
# yhat=b0+b1*x1
# where yhat is the prediction. b0 & b1 are coefficients found by optimizing the model on training data.

# %% [markdown]
# we can plot obs. at the previous time step i.e t-1 & next time step t+1 as a scatter plot.
#
# lag_plot(series) serves the purpose

# %%
from pandas.plotting import lag_plot
lag_plot(ts)
plt.show()

# %%
values=pd.DataFrame(ts.values)
dataframe= pd.concat([values.shift(1),values],axis=1)
dataframe.columns=['t-1','t+1']
result=dataframe.corr()
print(result)
# Out:
#           t-1       t+1
# t-1  1.000000  0.997464
# t+1  0.997464  1.000000

# %% [markdown]
# This shows a strong positive correlation between observation & lag=1 value.
# but it's a tedious approach. so go with autocorrelation_plot()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(ts)
plt.show()

# %% [markdown]
# pip install statsmodels --upgrade

# %%
from statsmodels.tsa.ar_model import AutoReg

# %%
x=ts.values

train,test= x[1:len(x)-36],x[len(x)-36:]

# %%
model= AutoReg(train,lags=1)
model_fit=model.fit()
print("coefficients: %s" % model_fit.params)
# Out:
# coefficients: [0.09394937 0.98962665]

# %%
predictions_A= model_fit.predict(start=len(train),end=(len(train)+len(test)-1),dynamic=False)

for i in range(len(predictions_A)):
  print('predicted=%f,expected=%f'%(predictions_A[i],test[i]))
# Out:
# predicted=6.328597,expected=6.200000
# predicted=6.356898,expected=6.200000
# predicted=6.384905,expected=6.200000
# predicted=6.412622,expected=6.200000
# predicted=6.440051,expected=6.100000
# predicted=6.467195,expected=6.100000
# predicted=6.494058,expected=6.100000
# predicted=6.520642,expected=6.000000
# predicted=6.546951,expected=6.000000
# predicted=6.572986,expected=6.000000
# predicted=6.598752,expected=6.000000
# predicted=6.624250,expected=6.000000
# predicted=6.649484,expected=5.900000
# predicted=6.674456,expected=5.900000
# predicted=6.699169,expected=5.800000
# predicted=6.723625,expected=5.800000
# predicted=6.747828,expected=5.700000
# predicted=6.771780,expected=5.700000
# predicted=6.795483,expected=5.700000
# predicted=6.818941,expected=5.700000
# predicted=6.842155,expected=5.600000
# predicted=6.865128,expected=5.600000
# predicted=6.887863,expected=5.500000
# predicted=6.910362,expected=5.500000
# predicted=6.932628,expected=5.400000
# predicted=6.954663,expected=5.400000
# predicted=6.976469,expected=5.300000
# predicted=6.998049,expected=5.300000
# predicted=7.019406,expected=5.200000
# predicted=7.040540,expected=5.200000
# predicted=7.061456,expected=5.200000
# predicted=7.082154,expected=5.200000
# predicted=7.102638,expected=5.100000
# predicted=7.122909,expected=5.100000
# predicted=7.142970,expected=5.000000
# predicted=7.162823,expected=5.000000

# %%
mse= mean_squared_error(test,predictions_A)
print("MSE36:",mse)
print("RMSE36:",np.sqrt(mse))
# Out:
# MSE36: 1.6192143070084972
# RMSE36: 1.2724835193465167

# %%
plt.plot(test)
plt.plot(predictions_A,color='red')
plt.show()

# %% [markdown]
# Time for Bayesian

# %%
df['DATE']=pd.to_datetime(df['DATE'])
df['Month']=df['DATE'].dt.month

# %%
df.head(13)
# Out:
#          DATE  values  Month
# 0  1980-01-01     3.1      1
# 1  1980-02-01     3.0      2
# 2  1980-03-01     3.1      3
# 3  1980-04-01     3.2      4
# 4  1980-05-01     3.3      5
# 5  1980-06-01     3.3      6
# 6  1980-07-01     3.4      7
# 7  1980-08-01     3.5      8
# 8  1980-09-01     3.5      9
# 9  1980-10-01     3.6     10
# 10 1980-11-01     3.8     11
# 11 1980-12-01     3.9     12
# 12 1981-01-01     4.0      1

# %%
ts=df['values']

# %%
ts.plot()

# %%
y1=ts.values
x1=ts.index.values
x=x1.reshape(-1,1)
y=y1.reshape(-1,1)
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression().fit(x,y)

# %%
print("cofficient is:",reg.coef_)
print("reg_intercept:",reg.intercept_)
# Out:
# cofficient is: [[0.00054695]]
# reg_intercept: [8.00305615]

# %%
y_reg= 8 + 0.0005*x1

# %%
x1=np.array(x1)
y1=np.array(y1)

# %%
def plot_df(x,y,y_reg,title='',xlabel='month',ylabel='value',dpi=100):
  plt.figure(figsize=(6,4),dpi=dpi)
  plt.plot(x,y_reg,color='tab:red')
  plt.plot(x,y,color='tab:blue')
  plt.gca().set(title=title,xlabel=xlabel,ylabel=ylabel)
  plt.show()

# %%
plot_df(x=x1,y=y1,y_reg=y_reg,title='unemployment rate')

# %%
import pymc3 as pm

# %%
beta=8
alpha=0.0005

# %%
df = ...
# pm.Normal('alpha', mu=0, sd=100) is random variable, named `alpha`,
# pm.Normal.dist(...) is distribution object used to create random variables
priors = {"Intercept": pm.Normal.dist(mu=8, sd=10),
          "Regressor": pm.Normal.dist(mu=0.005,sd=10)
          }

# %%
with pm.Model() as model:
  df =priors = {"beta": pm.Normal.dist(mu=8, sd=10),
          "alpha": pm.Normal.dist(mu=0.005,sd=10)
          }
  beta=pm.Normal('beta',mu= 8, sd=10)
  alpha=pm.Normal('alpha',mu=0.005,sd=10)
  mean=pm.Deterministic("mean",alpha+beta*x)
  std=pm.Uniform('std',0,100)       
  obs=pm.Normal("obs",mu=mean,sd=std,observed=y)
  trace=pm.sample(100000,step=pm.Metropolis())
  burned_trace=trace[20000:]
# Out:
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [std]
# >Metropolis: [alpha]
# >Metropolis: [beta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='101000' class='' max='101000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [101000/101000 01:06<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='101000' class='' max='101000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [101000/101000 00:58<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 100_000 draw iterations (2_000 + 200_000 draws total) took 124 seconds.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.plots.traceplot(burned_trace,varnames=['std','beta','alpha'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f63a0bfacf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63a0d8c0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f63a0ca7a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63a0b50550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f63a0b7e978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f63a0b2fda0>]],
#       dtype=object)

# %%
pm.plot_posterior(burned_trace,varnames=['std','beta','alpha'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f63a06ff6a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63a08876a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f63a309cac8>],
#       dtype=object)

# %%
beta_trace=burned_trace['beta']
pd.Series(beta_trace[:1000]).plot()

# %%
alpha_trace=burned_trace['alpha']
pd.Series(alpha_trace[:1000]).plot()

# %%
std_trace=burned_trace['std']
pd.Series(std_trace[:1000]).plot()

# %%
std_mean=std_trace.mean()
print(std_mean)
beta_mean=beta_trace.mean()
print(beta_mean)
alpha_mean=alpha_trace.mean()
print(alpha_mean)
# Out:
# 1.9699602272137515
# 0.0008041350458626712
# 7.941437568893738

# %%
train=train.values
test=test.values
test1=test1.values
test2=test2.values

# %%
len(train)
# Out:
# 432

# %% [markdown]
# Unemployment(t)=beta_mean*t +alpha_mean+error

# %%
length=36
x1=np.arange(length)
mean_trace=alpha_mean+ beta_mean*x1
normal_dist=pm.Normal.dist(0,sd=std_mean)
errors=normal_dist.random(size=length)
Y_gen= mean_trace+ errors
Y_reg1=mean_trace

# %%
plot_df(x=x1,y=Y_gen,y_reg=Y_reg1,title='Unemployment rate')

# %%
len(Y_reg1)
# Out:
# 36

# %%
len(test)
# Out:
# 36

# %%
from sklearn.metrics import mean_squared_error
errorb= mean_squared_error(test,Y_reg1)
print(errorb)
# Out:
# 5.404698764989714

# %%
print("RMSE:",np.sqrt(errorb))
# Out:
# RMSE: 2.324800801141834

# %%
print(error)
# Out:
# 0.0028555560690216057

# %% [markdown]
# MSE & RMSE FOR ARIMA
# MSE: 0.0028555560690216057
# RMSE: 0.05343740327730761

# %%
pred_new=(predictions+Y_reg1)/2

# %%
error_new= mean_squared_error(test,pred_new[1])
print(error_new)
# Out:
# 2.122731923567189

# %%
print(np.sqrt(error_new))
# Out:
# 1.456959822221323
